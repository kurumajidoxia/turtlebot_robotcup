# %%
import rospy
import math
import numpy as np
import cv2
import time

from sensor_msgs.msg import Image
from aruco_msgs.msg import MarkerArray
from cv_bridge import CvBridge, CvBridgeError
from geometry_msgs.msg import Twist
from nav_msgs.msg import Odometry
from operator import itemgetter

bridge = CvBridge()

# %%
rospy.init_node('turtlebot_singleplayer', anonymous=True)
rospy.sleep(0.5)
lower_blue = (0,0,120)
upper_blue = (100,100,255)
lower_red = (200,0,0)
upper_red = (255,100,100)

# %%
def callback_color(msg):
    
    #start_time = time.time()
    
    global x_ball
    global y_ball
    global dist_ball
    color_timestamp = msg.header.stamp
    color_img = bridge.imgmsg_to_cv2(msg, "rgb8")
    mask_blue = cv2.inRange(color_img, lower_blue, upper_blue)
    mask_red = cv2.inRange(color_img, lower_red, upper_red)
    kernel = np.ones((5,5),np.uint8)
    erosion_blue = cv2.erode(mask_blue,kernel,iterations = 1)
    dilation_blue = cv2.dilate(erosion_blue,kernel,iterations = 3)
    erosion_red = cv2.erode(mask_red,kernel,iterations = 1)
    dilation_red = cv2.dilate(erosion_red,kernel,iterations = 3)
    mask = cv2.bitwise_or(dilation_blue, dilation_red)
    im, cnt, hrc = cv2.findContours(mask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnt.sort(key=cv2.contourArea, reverse=True)
    if cnt:
        x, y, w, h = cv2.boundingRect( cnt[0] )
        if (w*h > 2000):
            x_ball = x+w/2
            y_ball = y+h/2
            dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
        else:
            x_ball = 0
            y_ball = 0
            dist_ball = None
    else:
        x_ball = 0
        y_ball = 0
        dist_ball = None
    
    #print "time %f"%(time.time() - start_time)
    
    #cv2.rectangle(img, (x,y), (x+w,y+h), (255,0,255), 2)
    #plt.imshow(img);

# %%
def callback_depth(msg):
    global depth_img
    global depth_timestamp
    depth_timestamp = msg.header.stamp
    depth_img = bridge.imgmsg_to_cv2(msg, "32FC1")

# %%
def callback_odom(data):
    global x
    global y
    global theta
    position = data.pose.pose.position
    orientation = data.pose.pose.orientation
    x = round(position.x, 3)
    y = round(position.y, 3)
    theta = round(2*math.atan2(orientation.z,orientation.w), 3)
    if theta < 0:
        theta = 2*math.pi + theta

# %%
def callback_image(msg):
    global marker_img
    global marker_timestamp
    marker_img_timestamp = msg.header.stamp
    marker_img = bridge.imgmsg_to_cv2(msg, "rgb8")

def callback_array(msg):
    global marker_array
    global marker_array_timestamp
    marker_array_timestamp = msg.header.stamp
    marker_array = msg.markers

# %%
#turn to certain theta
def turnToTheta(theta_tar):
    twist = Twist()
    twist.linear.x = 0.0
    ang_diff = theta_tar - theta
    s = np.sign(ang_diff)
    if abs(ang_diff) > math.pi:
        s *= -1.0
        ang_diff = 2*math.pi - abs(ang_diff)
    ang_vel = s*ang_diff*0.6
    if abs(ang_vel) < 0.2:
        ang_vel = np.sign(ang_vel)*0.2
    twist.angular.z = ang_vel
    r = rospy.Rate(10)
    while(abs(theta_tar-theta) > 0.1):
        publisher.publish(twist)
        r.sleep()
        ang_diff = abs(theta_tar - theta)
        if ang_diff > math.pi:
            ang_diff = 2*math.pi - ang_diff
        ang_vel = s*ang_diff*0.6
        if abs(ang_vel) < 0.2:
            ang_vel = np.sign(ang_vel)*0.2
        twist.angular.z = ang_vel
        #print theta

# %%
subscriber_color = rospy.Subscriber("/camera/rgb/image_rect_color", Image, callback_color)
subscriber_depth = rospy.Subscriber("/camera/depth/image_rect", Image, callback_depth)
subscriber = rospy.Subscriber("odom", Odometry, callback_odom)
publisher = rospy.Publisher('cmd_vel_mux/input/teleop', Twist, queue_size=10)
subscriber_array = rospy.Subscriber("/aruco_marker_publisher/markers", MarkerArray, callback_array)
# Out:
# [ERROR] [1510944161.443425]: bad callback: <function callback_color at 0x7f782805cb90>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-3-6e3d4d883edb>", line 25, in callback_color
#     dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
# NameError: global name 'depth_img' is not defined
#
# [ERROR] [1510944161.467878]: bad callback: <function callback_color at 0x7f782805cb90>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-3-6e3d4d883edb>", line 25, in callback_color
#     dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
# NameError: global name 'depth_img' is not defined
#
# [ERROR] [1510944161.490900]: bad callback: <function callback_color at 0x7f782805cb90>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-3-6e3d4d883edb>", line 25, in callback_color
#     dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
# NameError: global name 'depth_img' is not defined
#
# [ERROR] [1510944161.505984]: bad callback: <function callback_color at 0x7f782805cb90>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-3-6e3d4d883edb>", line 25, in callback_color
#     dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
# NameError: global name 'depth_img' is not defined
#
# [ERROR] [1510944161.539820]: bad callback: <function callback_color at 0x7f782805cb90>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-3-6e3d4d883edb>", line 25, in callback_color
#     dist_ball = np.nanmean(depth_img[y:y+h,x:x+w])
# NameError: global name 'depth_img' is not defined

# %%
subscriber = rospy.Subscriber("odom", Odometry, callback_odom)
publisher = rospy.Publisher('cmd_vel_mux/input/teleop', Twist, queue_size=10)

# %%
#Turn around look for the ball and the gate
gate_error, gate_dist, gate_theta = [],[],[] # Whether it was found, and its theta coordinate, and x 
twist = Twist()
#We need this if we want to turn full circle
theta_initial = theta
half_circle = False
marker_array = None
m = None
#Find gate
while (abs(theta-theta_initial)>0.1 or (half_circle != True)):
    if(theta - 6.1 > 0):
        half_circle = True
    twist.angular.z = 0.2
    r = rospy.Rate(10)
    for i in range(5):
        publisher.publish(twist)
        r.sleep()
        
    try:
        m = marker_array[0]
        
        
        gate_error.append(abs(m.pose.pose.orientation.x))
        gate_dist.append(abs(m.pose.pose.orientation.z))
        gate_theta.append(theta)
        print m.pose.pose.orientation.x,m.pose.pose.orientation.y,m.pose.pose.orientation.z
        marker_array = None
    except TypeError:
        continue

index = min(enumerate(gate_error), key=itemgetter(1))[0]
theta_gate = gate_theta[index]
dist_gate = gate_dist[index]
# Out:
# 0.170935919023 0.743387354005 -0.620773588724
# 0.120398492566 0.75774814588 -0.627196350316
# -0.189839360207 -0.666273905329 0.702779560884
# 0.121567406125 0.756511782828 -0.63055155171
# 0.0622066205621 0.759916834366 -0.64368580786
# 0.0835253242947 0.780978203943 -0.613203076619
# -0.138358403236 -0.662402616643 0.728339861546
# 0.02956548262 0.747710031247 -0.663266536298
# /usr/lib/python2.7/dist-packages/numpy/lib/nanfunctions.py:675: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# 0.00327019988542 0.73968878737 -0.672794382028
# -0.0912292343162 -0.69121231522 0.713788161389
# 0.0494286424618 0.71773036058 -0.694188763935
# -0.065535259192 0.723436305532 -0.681432339422
# -0.10411354253 0.742093286521 -0.649612555775
# -0.105271647462 0.708138761159 -0.68639743306
# -0.133989957062 0.722026899165 -0.65855757592
# 0.146753594491 -0.685842347021 0.692175011922
# -0.183548491969 0.689919414794 -0.666535912482
# -0.207688229009 0.697443816976 -0.639127535988

# %%
turnToTheta(theta_gate)

# %%
#Find ball
ball = [False, 0,0]
twist = Twist()
#We need this if we want to turn full circle
theta_initial = theta
half_circle = False

ball_pos = []
theta_list = []
while (abs(theta-theta_initial)>0.1 or (half_circle != True)):
    if(theta - 6.1 > 0):
        half_circle = True
        
    twist.angular.z = 0.2
    r = rospy.Rate(10)
    for i in range(5):
        publisher.publish(twist)
        r.sleep()
    if x_ball:
        if not dist_ball:
            dist_ball = 100
        ball_pos.append([x_ball, y_ball, theta, dist_ball])
        theta_list.append(theta)
        print dist_ball, theta
ball_np = np.array(ball_pos)
idx = (np.abs(ball_np[:,0]-320)).argmin()
#idx = (np.abs(ball_np[:,3])).argmin()
ball_pos = ball_np[idx]
ball_dist = np.nanmin(ball_np[:,3])
ball_theta = ball_pos[2]
print ball_pos

#Theta cleanup
sd = np.std(ball_np[:,2])
mean = np.mean(ball_np[:,2])
final_list = [x for x in theta_list if (x > mean - sd)]
final_list = [x for x in final_list if (x < mean +  sd)]
ball_theta = sum(final_list) / float(len(final_list))
# Out:
# 3.13657 3.168
# 1.66072 3.644
# 0.876174 3.752
# 0.69525 3.85
# 0.735691 3.943
# 0.738258 4.034
# 0.749024 4.134
# 0.763446 4.232
# 0.759297 4.323
# 0.74719 4.423
# 0.748286 4.524
# 0.705621 4.629
# 0.693905 4.722
# 0.650337 4.81
# 0.708471 4.918
# 1.55517 5.016
# 1.84184 0.469
# 2.11166 0.971
# 2.12044 1.052
# 1.98791 1.153
# 1.94789 1.257
# 1.85715 1.351
# 1.91827 1.449
# 1.04035 1.544
# 1.0344 1.648
# nan 2.348
# 2.96835 2.434
# 3.20977 2.52
# 3.31317 2.622
# 3.37855 2.736
# 3.4579 2.851
# 3.43523 2.935
# 3.35496 3.039
# [ 322.          172.            2.935         3.43523264]

# %%
turnToTheta(ball_theta)
# Out:
# [ERROR] [1510942697.531366]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.566668]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.634348]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.670298]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.739023]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.773985]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.808907]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.841387]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.874849]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.951121]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942697.980920]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.048391]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.084368]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.116273]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.152722]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.186141]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.222122]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.253996]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.292034]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.331651]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.358454]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.398725]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.460039]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.496887]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.565376]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.599500]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.636907]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.670002]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.738117]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.817697]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.877498]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.910232]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.953115]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942698.987335]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.054801]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.088454]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.158097]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.190750]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.228813]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.267046]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.293341]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.326972]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.364531]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.394943]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.466894]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.497723]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.534390]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.566551]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.600989]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.634993]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.669898]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.741857]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.777595]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.809673]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.843902]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.877129]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.914338]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.949014]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942699.981504]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.049365]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.084339]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.153596]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.187810]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.222463]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.256761]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.291403]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.326617]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.361036]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.397792]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.466315]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.497773]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.539007]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.569698]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.609647]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.669099]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.705737]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.739901]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.774774]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.808804]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.882380]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942700.987274]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.021114]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.052450]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.085946]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.128644]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.164953]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.198778]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.260867]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.308311]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.370399]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.401765]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.434801]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.469558]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.539405]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.573436]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.609529]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.673333]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.708341]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.752395]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.775916]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.811106]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.845522]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.880872]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.920810]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.966871]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942701.989009]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.018613]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.086002]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.121763]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.157019]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.191851]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.226028]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.266812]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.293988]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.327974]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.364421]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.410563]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.466007]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.497894]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.539700]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.603876]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.644770]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.674672]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.708543]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942702.776888]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# ...
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942745.798982]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942745.826577]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942745.893890]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942745.928948]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942745.976515]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.006491]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.032200]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.064041]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.098775]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.140077]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.170766]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.203481]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.271808]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.306690]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.341123]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.374616]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.414057]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.443994]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.479652]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.512397]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.582392]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.614635]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.649168]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.684135]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.718312]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.752990]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.788322]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.822335]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.900215]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.934681]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.961364]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942746.993980]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.030071]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.099677]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.202392]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.237354]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.271390]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.304591]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.340153]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.372054]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'
#
# [ERROR] [1510942747.409454]: bad callback: <function callback_color at 0x7faa64d2b9b0>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-4-f23636942a4c>", line 3, in callback_color
#     start_time = time.time()
# AttributeError: 'int' object has no attribute 'time'

# %%
#calculate angle and distance to go to he position to kick the ball
dist_BT = 0.5
ang_GRB = abs(theta_gate - ball_theta)
dist_RB = ball_dist
dist_RG = dist_gate
dist_BG = math.sqrt(pow(dist_RG,2) + pow(dist_RB,2) - 2*dist_RG*dist_RB*math.cos(ang_GRB))
ang_GBR = math.acos((pow(dist_BG,2) + pow(dist_RB,2) - pow(dist_RG,2)) / (2*dist_BG*dist_RB))
ang_RBT = math.pi - ang_GBR
dist_RT = math.sqrt(pow(dist_RB,2) + pow(dist_BT,2) - 2*dist_RB*dist_BT*math.cos(ang_RBT))
ang_BRT = math.acos((pow(dist_RB,2) + pow(dist_RT,2) - pow(dist_BT,2)) / (2*dist_RB*dist_RT))
ang_BTR = math.acos((pow(dist_BT,2) + pow(dist_RT,2) - pow(dist_RB,2)) / (2*dist_BT*dist_RT))
ang_back = math.pi - ang_BTR
if ball_theta < theta_gate:
    theta_tar = ball_theta - ang_BRT
    theta_back = theta_tar + ang_back
else:
    theta_tar = ball_theta + ang_BRT
    theta_back = theta_tar - ang_back

# %%
#move to the target position
turnToTheta(theta_tar)
time = int(round(dist_RT*40))
twist = Twist()
twist.linear.x = 0.2
twist.angular.z = 0.0
r = rospy.Rate(10)
for i in range(time):
    publisher.publish(twist)
    r.sleep()

# %%
turnToTheta(theta_back)

# %%
#find the ball
print [x_ball, y_ball]
twist = Twist()
twist.linear.x = 0.0
twist.angular.z = -0.3
r = rospy.Rate(10)
while x_ball == 0:
    for i in range(5):
        publisher.publish(twist)
        r.sleep()
print "found the ball!!"
print [x_ball, y_ball]
# Out:
# [0, 0]
# found the ball!!

# %%
def getAngleDiff():
    x_theta = x_ball - img_w/2
    y_theta = img_h - y_ball
    angle = math.pi/2 - math.atan2(y_theta,x_theta)
    return angle

# %%
getAngleDiff()
# Out:
# -0.3337981642508283

# %%
#turn to ball
print (x_odom,y_odom,theta_odom)
twist = Twist()
angle = getAngleDiff()
twist.linear.x = 0.0
if angle > 0:
    twist.angular.z = -0.2
else:
    twist.angular.z = 0.2
r = rospy.Rate(10)
while abs(angle) > 0.1:
    for i in range(5):
        publisher.publish(twist)
        r.sleep()
    angle = getAngleDiff()
print "finish", (x_odom,y_odom,theta_odom)
# Out:
# (0.447, 0.296, 0.679)
# 1.05416804189
# 1.05416804189
# 1.05711463903
# 1.05711463903
# 1.05711463903
# 1.05416804189
# 1.05416804189
# 0.906464897965
# 0.906464897965
# 0.141897054604
# 0.141897054604
# 0.141897054604
# -0.70690806076
# finish (0.448, 0.296, -0.763)
# not big enough 407.0
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball
# no ball

# %%
print theta_gate
print ball_theta
# Out:
# 3.596
# 3.32735294118

# %%
print theta_back
# Out:
# 2.62554277113
